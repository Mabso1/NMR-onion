# %% [markdown]
# # Introduction
# This notebook demonstrates how the NMR-onion algortimn works. The data used in this demo is the sample 1 experiment 2 dataset found in the github datafolder. The algoritmn is based around the steps of peak detection, digital filtering a region of interst (ROI), model fitting, model selection and uncertainty estimation
#
#
# first step is to load all the function requried to run the program. The import part is to set the path variable correctly to the folder where you have downloaded all the functions.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore", category=np.ComplexWarning)# disable plot warnings 
path="/home/mathies/Desktop/nmr onion/NMR onion final" # set to the path in which NMR onion folder is stored
sys.path.append(path)
import nmrglue as ng
from data_import import import_data
from model_caller import onion_model_call,onion_bootstrap_call
from helper_functions import get_amps, plot_freq_CIs, freq_hz,ppm_axis1,t_disrecte,time_series,ppm2hz,hz2ppm,amp_ratio,calc_couplings,result_csv,result_csv_noboot,getoverlaps,count_overlaps
from model_prediction_fuctions import pred,preds_split,single_sinusoid,model_auto_select,par_hat_output
from peak_detection import peak_detection,peaks2hz,signal_points
from onion_filter_experimental import onion_filter,baseline_arPLS,data2fit

# %% [markdown]
# # Importing the data
# To import processed bruker data from Topspin, the import_data function is called. All one need to do is to set the data_path variable as /../dataset_name/exp_number/pdata/1. This will let you import the processed FID, Number of datapoints (N), sweep width in Hz (fs), transmitter position (O1), spectrometor frequecy (SF) and sweep width ppm (fs_ppm). additionally one can zerofill data if needed by stating true or false. It should be noted that the processed FID does not need to have undergone hard preprocessing, but should be as close to the raw data as possible. The reason the processed FID is loaded is due to the NMR-glue modoule supressing the group delay directly from the pdata.
#
# The time axis (s),frequency axis(hz) and frequency axis(ppm) is then automatically defined by calling the freq_hz,ppm_axis1,t_disrecte,time_series functions based on the import data output.
#
#
# Currently only Bruker data is supported in this function for other formats the source code of the import function can be cominbed with other vendor formats by replacing the bruker import module from NMRglue with a different NMRglue module. Alternatively one may import a CSV file contaninig spectral data and do an inverse fourier transformation - more import options will be added in the futre

# %%
# set your own data_path
data_path="/home/mathies/Desktop/nmr onion/article data experiment 2/DTU800_150922_CHG_MMS052002(1)/DTU800_150922_CHG_MMS052002/10/pdata/1"
sys.path.append(data_path)

# import the data with needed process and aqusition parameters
# import data,data length, sample rate, O1, spectromtor frequency, sweep width (ppm), O1p, zerofill data if needed
data,N,fs,O1,SF,fs_ppm,O1p=import_data(path=data_path,zerofill=False)

# define discrete time (tn) and measure timed (t)
tn=t_disrecte(N)
t=time_series(tn=tn,fs=fs)

# define ppm axis
freq=freq_hz(tn=tn, fs=fs)
ppm_val=ppm_axis1(time=t, O1=O1, fs=fs, fs_ppm=fs_ppm)

# fourier transfrom raw data
y_fft_raw=np.fft.fftshift(np.fft.fft(data))

# check the data import works by plotting
plt.xlabel('ppm')  
plt.ylabel('Intensity')
plt.title("NMR Spectrum")  
plt.plot(ppm_val,y_fft_raw,color="blue")
#plt.xlim(,) # zoom x-axis
#plt.ylim(0,0.13*10**7) # zoom y-axis
plt.show()

# plot the time series
plt.title("FID")  
plt.plot(t,data,color="green")
plt.xlabel('time(s)')  
plt.ylabel('Intensity')
plt.show()

# %% [markdown]
# # Peak detection and ROI selection
# Following data importing, selection of a ROI is requried for the alogrithm to work computationally effecient. Addtionally a good inital estimates of the frequency values must be given due to the mutimodal nature of the parameter space. The ROI is generated based on a digital filter which cuts out the ROI and adds synthetic noise outside the ROI. Here one needs to select the ROI and noise region for the filter to work. we choose 3.35:3.6 ppm for the ROI and -0.2:-0.1 for the noise region (other regions could also have been choosen).

# %%
#filtering the data
ROI1=np.array([3.35,3.6])
target_ROI=ROI1

high_ppm=target_ROI[1]# set ppm values for region cuts
low_ppm=target_ROI[0]# set ppm values for region cuts

noise_region=[-0.2, -0.1,] # low to high ppm

# apply digital filter to get region of interest and estimated noise level
y_filt,noise_level=onion_filter(low_ppm, high_ppm, noise_region, data, fs, SF, O1p)

# fourier transform filtered data
y_fft_filt=np.fft.fftshift(np.fft.fft((y_filt)))

plt.xlabel('ppm')  
plt.ylabel('Intensity')
plt.title("filtered region ("+str(low_ppm)+"-"+str(high_ppm)+"ppm)",) 
plt.plot(ppm_val,y_fft_filt,color="blue")
plt.xlim(low_ppm-0.1,high_ppm+0.1)
plt.show()

# %% [markdown]
# When detecting peaks within the filtered regions. Two options may be applied, either use the peak detection algoritmn on filtered region to detect peaks or use the detection algorithmn on the full spectrum. In this case the filtred spectrum detection was applied. Three parameters are given for the detection algorithmn that is a width parameter, noise_roi and noise_peaks.
#
# Witdh: Controls how large a witdh based on the fwhm of the peaks should be indculeded in the detection. defualt valus is set at 1.0, higher values decrease number of peaks detected (reasonable range:0.8:2.5)
#
# noise_roi: Controls how large the error margin for the automated signal detection should be. defualt value is set at 4, lower values increase number of peaks detected (reasonable range: 1.0:4.0)
#
# noise_peaks: Controls how large the noise floor should be. defualt value set at 2.0, lowering number increases peaks detected, increasing number decreases number of peaks detected (reasonable range: 1.0:20)
#
# Alternatively the safety net of SNR (in dB) is also included such that no peaks below a certain SNR is included
#
# Prior to detection an addtional baseline correction might be needed using the ALSpls algoritmn which requries the input of a lamba value. the defualt value is set at lam=10^5 and this usually works well in tandem with the detection algoritmn.

# %%
# %%capture 
# remove capture when trying out yourself! this is made here so the long computational printing does not take up too much space 

# baseline correction of full spectrum, uncomment if needed
_, y_fft_raw_als, info = baseline_arPLS(y_fft_raw, lam=1e5, niter=20,
                                        full_output=True)

# baseline correction of filtered spectrum, uncomment if needed
#_, y_fft_filt_als, info = baseline_arPLS(fft_raw, lam=1e5, niter=20,
 #                                       full_output=True)

# detect peaks in ppm:
#user parameters: 
#width: controls peak width cut off, the lower the value, the more peaks included, 0.8 is the default value
#noise_peaks: controls lower boundery of noise floor, the lower the value, the more peaks included, 2 is the defualt value, but for a noise baseline higher values are needed
#noise_roi : controls the mask size of each detected signal region, the lower the value, the larger the regions, 4 is the defualt value
omega_ppm=peak_detection(ppm_val=ppm_val, y=y_fft_raw_als, width=0.8, noise_roi=4, noise_peaks=10.0, t=t, fs=fs)

# convert detected peaks to hz 
omega_hz_filtered=peaks2hz(omega_ppm,high_ppm,low_ppm,SF,O1p) # convert to hz and make sure only peaks within ROI is present
    
# store the detected peak intensitiy values and ppm/hz values (set ppm_out=True for ppm output, else hz output)
ROI_hz_points,ROI_signal_points=signal_points(omega_hz_filtered=omega_hz_filtered, freq=freq, y=y_filt, SF=SF, O1p=O1p,ppm_out=False)

ROI_ppm_points=hz2ppm(np.array(ROI_hz_points),SF,O1p) # point values in ppm

# %%
# compute SNR in dB (make sure nothing below 0 is included)
SNR_db=np.log10(ROI_signal_points/np.std(noise_level))
idx=np.where(np.real(SNR_db)>0)

omega_hz_filtered=omega_hz_filtered[idx]

# return SNR filtered omega
omega_hz_filtered=omega_hz_filtered[idx]

# check the peak dection within the region
plt.xlabel('ppm')  
plt.ylabel('Intensity')
plt.title("Peaks detected ("+str(low_ppm)+"-"+str(high_ppm)+"ppm)",) 
plt.plot(ppm_val,y_fft_filt,color="blue")
plt.xlim(low_ppm,high_ppm)
plt.xlim(3.43,3.36)
plt.ylim(-100000,1*10**6.5)
for i in range(0,len(omega_hz_filtered)):
    plt.scatter(ROI_ppm_points[idx[0][i]],ROI_signal_points[idx[0][i]],color="red")

# %% [markdown]
# # Running the models and model selection
# The NMR onion includes 3 models of which the best is selected, being either the skewed lortentzian model, skewed psedou voigt model or the skewed generlized voigt model.in the future the fitting process will be run in parallel. it shoudl be noted that it is also possible to compare with non-skewed versions of models by setting model name as "pvoigt","lorentzian" or "genvoigt" instead. Each model is run with 20 epochs and a learning rate of 0.1 and an exponential learning rate scheduler is applied to lower the learning rate per epoch
#
# The model selection is based of AIC and BIC from which the lowest value is choosen, pointing back to a specfic model. This is done by the model_auto_selection function, one can either choose this to be based on BIC (defualt) or or AIC by setting BIC=False. A table is also provided should it be needed to see the actualt BIC and AIC values
#
# For this dataset, the ROI was best fitted by the skewed generlized voigt model(fit3), or as in the article the skewed powerlaw model. The restuls of the best model is stored as par_res for the parameter values, k for the number of components detected and model for the best model name

# %%
#%%capture 
# remove capture when trying out yourself! this is made here so the long computational printing does not take up too much space 
# lortentzian model
onion_model_call(model_name="skewed_lorentzian",omega_hz_filtered=omega_hz_filtered,tn_new=tn,t_new=t,fs_new=fs,y_norm=y_filt/np.linalg.norm(y_filt))
# Out:
# tensor(0.0832, dtype=torch.float64, grad_fn=<AsStridedBackward0>)
# loss: 0.08315259162065519
# loss: 0.08297001295580939
# loss: 0.0829681868956548
# loss: 0.08296816863503104
# loss: 0.08296816845242198
# loss: 0.0829681684505974
# loss: 0.08296816845057685
# loss: 0.08296816845057672
# loss: 0.08296816845057675
# loss: 0.08278544920800221
# loss: 0.08278362196354459
# loss: 0.08278360369109665
# loss: 0.08278360350837388
# loss: 0.08278360350654308
# loss: 0.08278360350652436
# loss: 0.08278360350652426
# loss: 0.08278360350652426
# loss: 0.0826008165510214
# loss: 0.08259898883593018
# loss: 0.08259897055880158
# loss: 0.08259897037603914
# loss: 0.08259897037420778
# loss: 0.08259897037418676
# loss: 0.08259897037418665
# loss: 0.08259897037418665
# loss: 0.08259897037418665
# Epoch:01/20 Loss: 8.25990e-02
# loss: 0.08259897037418665
# loss: 0.08247101257217758
# loss: 0.08246973314420958
# loss: 0.08125002909524065
# loss: 0.08125002909524065
# loss: 0.08125002909524065
# Epoch:18/20 Loss: 8.12500e-02
# loss: 0.08125002909524065
# loss: 0.08124973365587046
# loss: 0.08124973070148175
# loss: 0.08124973067193735
# loss: 0.08124973067164068
# loss: 0.08124973067163531
# loss: 0.08124973067163531
# loss: 0.08124943523308156
# loss: 0.08124943227870098
# loss: 0.081249432249156
# loss: 0.08124943224886132
# loss: 0.08124943224885865
# loss: 0.08124943224885807
# loss: 0.08124943224885807
# loss: 0.08124913681112826
# loss: 0.08124913385675786
# loss: 0.08124913382721327
# loss: 0.08124913382692496
# loss: 0.0812491338269231
# loss: 0.08124913382692311
# loss: 0.0812491338269231
# Epoch:19/20 Loss: 8.12491e-02
# loss: 0.0812491338269231
# loss: 0.08124892702101807
# loss: 0.08124892495297137
# loss: 0.08124892493228253
# loss: 0.0812489249320818
# loss: 0.0812489249320806
# loss: 0.08124892493208057
# loss: 0.08124892493208057
# loss: 0.08124871812658886
# loss: 0.08124871605853344
# loss: 0.08124871603784924
# loss: 0.08124871603764998
# loss: 0.08124871603764872
# loss: 0.0812487160376487
# loss: 0.0812487160376487
# loss: 0.0812485092325523
# loss: 0.08124850716451207
# loss: 0.08124850714382231
# loss: 0.08124850714361315
# loss: 0.08124850714361197
# loss: 0.08124850714361195
# loss: 0.08124850714361195
# loss: 0.08124850714361195
# Epoch:20/20 Loss: 8.12485e-02
# 46.09855031967163
# {'par': [array([ 5.48073660e-04,  9.91964242e-04,  1.13945699e-03,  1.50712098e-03,
#           2.63443822e-03,  1.19690894e-03,  5.68282180e-04,  5.85996329e-04,
#           2.24329985e-04,  4.00393993e-03,  4.03030740e-03,  3.84200464e-03,
#           1.93469977e-03,  5.13731852e-03,  5.66237263e-03,  6.11066241e-03,
#           5.71873319e-03,  4.22281701e-03,  8.58988188e-04,  6.39576483e-04,
#           9.01709922e-04,  1.29428741e-02,  4.76877418e-03,  3.42937516e-03,
#           4.05675218e-03,  2.58181792e-03,  1.41792200e-03, -1.55122318e+03,
#          -1.55591528e+03, -1.56061165e+03, -1.56295314e+03, -1.56735235e+03,
#          -1.57175773e+03, -1.57410029e+03, -1.57879704e+03, -1.58320111e+03,
#          -1.59876004e+03, -1.60110350e+03, -1.60286017e+03, -1.60579040e+03,
#          -1.61049627e+03, -1.61166205e+03, -1.61371364e+03, -1.61517368e+03,
#          -1.67094495e+03, -1.67328596e+03, -1.67652064e+03, -1.67768837e+03,
#          -1.68208630e+03, -1.68412847e+03, -1.68795351e+03, -1.69294519e+03,
#          -1.69498916e+03, -1.69909941e+03,  7.53093800e-01,  5.19815509e-04,
#           3.49702843e-04,  4.17280499e-04,  7.09328432e-05, -6.67426805e-05,
#           1.41909370e-04, -1.43239515e-04, -5.36066845e-05,  8.75965818e-05,
#           4.47875170e-04,  2.08383494e-04, -1.72382838e-05, -2.58935192e-04,
#           3.51707171e-04, -1.00767946e-04, -2.49749808e-04, -6.55914221e-04,
#           2.92837511e-04, -8.68788366e-05,  3.01418735e-04, -4.11771060e-05,
#          -2.57353023e-04, -9.38695003e-04, -3.54831608e-04, -1.74545063e-04,
#          -7.60168966e-04, -6.40816108e-04])],
#  'residuals': [array([ 0.10210323-4.58828440e-04j,  0.04902163-8.93177332e-02j,
#          -0.0541055 -8.59414083e-02j, ..., -0.00203248-3.90431580e-03j,
#          -0.00449083-9.17428155e-05j, -0.00228017+3.91881018e-03j])],
#  'peak_numbers': 27,
#  'BIC_model': -594842.7902361453,
#  'AIC_model': -596365.1378849059}

# %%
#%%capture 
# remove capture when trying out yourself! this is made here so the long computational printing does not take up too much space 
# psedou voigt model
fit2=fit2=onion_model_call(model_name="skewed_pvoigt",omega_hz_filtered=omega_hz_filtered,tn_new=tn,t_new=t,fs_new=fs,y_norm=y_filt/np.linalg.norm(y_filt))
# Out:
# loss: 0.07961867421646564
# loss: 0.07837845385670261
# loss: 0.07836603891226553
# loss: 0.07836591476206321
# loss: 0.0783659135205588
# loss: 0.07836591350815245
# loss: 0.0783659135080218
# loss: 0.0783659135080196
# loss: 0.07836591350801957
# loss: 0.07836591350801957
# loss: 0.07711173521454101
# loss: 0.07709918394099807
# loss: 0.07709905842762795
# loss: 0.07709905717249435
# loss: 0.07709905715994489
# loss: 0.07709905715982138
# loss: 0.0770990571598205
# loss: 0.0770990571598205
# loss: 0.07583198365738664
# loss: 0.07581930145426977
# loss: 0.07581917463131799
# loss: 0.07581917336308523
# loss: 0.07581917335040189
# loss: 0.0758191733502752
# loss: 0.07581917335027423
# loss: 0.07581917335027423
# loss: 0.07581917335027423
# Epoch:01/20 Loss: 7.58192e-02
# loss: 0.07581917335027423
# loss: 0.07492330625814003
# loss: 0.07491433967744901
# loss: 0.07491425001092489
# loss: 0.07491424911426098
# loss: 0.07491424910529185
# loss: 0.07491424910520462
# loss: 0.07491424910520397
# loss: 0.07491424910520394
# loss: 0.07491424910520394
# loss: 0.07401163269611549
# loss: 0.07400259781175346
# loss: 0.07400250746211567
# loss: 0.07400250655862625
# loss: 0.0740025065495897
# loss: 0.07400250654950177
# loss: 0.074002506549501
# loss: 0.074002506549501
# loss: 0.07309317149634408
# loss: 0.07308406932389687
# loss: 0.0730839783013898
# loss: 0.0730839773911668
# loss: 0.07308397738206646
# loss: 0.07308397738197497
# loss: 0.07308397738197427
# loss: 0.07308397738197428
# loss: 0.07308397738197427
# Epoch:02/20 Loss: 7.30840e-02
# loss: 0.07308397738197427
# loss: 0.07244313718513534
# loss: 0.07243672451840427
# loss: 0.07243666039134974
# loss: 0.07243665975008118
# loss: 0.0724366597436678
# loss: 0.07243665974360058
# loss: 0.0724366597436
# loss: 0.07243665974359999
# loss: 0.07243665974359997
# loss: 0.07243665974359997
# loss: 0.07179289218836088
# loss: 0.07178645078806109
# loss: 0.07178638637373173
# loss: 0.07178638572958726
# loss: 0.07178638572314675
# loss: 0.07178638572307924
# loss: 0.07178638572307898
# loss: 0.07178638572307897
# loss: 0.07178638572307897
# loss: 0.07113999829032039
# loss: 0.0711335314748766
# loss: 0.07113346680648204
# loss: 3.298888880996679e-05
# loss: 3.298888880996239e-05
# loss: 3.298888880995038e-05
# loss: 3.298888880994843e-05
# loss: 3.298888880994843e-05
# loss: 3.294785767248601e-05
# loss: 3.294744753693765e-05
# loss: 3.294744343547007e-05
# loss: 3.2947443394383636e-05
# loss: 3.294744339408502e-05
# loss: 3.294744339403402e-05
# loss: 3.294744339401557e-05
# loss: 3.294744339401587e-05
# loss: 3.294744339401557e-05
# Epoch:20/20 Loss: 3.29474e-05
# 107.26674365997314

# %%
# find parameter error of best model
model_compare_BIC=np.array([fit1['BIC_model'],fit2['BIC_model'],fit3['BIC_model']])
model_compare_AIC=np.array([fit1['AIC_model'],fit2['AIC_model'],fit3['AIC_model']])

model_compare_table=pd.DataFrame(({'skewed_lorentzian':(model_compare_BIC[0],model_compare_AIC[0]),
               'skewed_psedou_voigt':(model_compare_BIC[1],model_compare_AIC[1]),
               'skewed_generlized_voigt':(model_compare_BIC[2],model_compare_AIC[2]),
    }))

# make a list of fits
fits=([fit1,fit2,fit3])

par_res,model,k=model_auto_select(model_compare_BIC,model_compare_AIC,fits,omega_hz_filtered,BIC=True)
print(model_compare_BIC) # print BIC values, 0 inidicates no covergence
print(model_compare_AIC) # print AIC values, 0 indicates no convergence
print(model) # print the best model name
# Out:
# [-594842.79023615 -767596.12533918 -833301.71797167]
# [-596365.13788491 -769625.9222042  -835331.51483668]
# skewed_genvoigt

# %% [markdown]
# # Model output
# Now that each model has been fitted and the best model is choosen, the next step is to extract the relvant parameters for ROI identification and view how well the model predicted the spectrum. Each value for the model is extracted as seen below. Both in the Hertz domain (O1 not added) and in the ppm domain

# %%
# get parameter output as vector  
par_hat=par_hat_output(best_model=model,par_res=par_res)

# get FID prediction
y_hat=pred(theta=par_hat,m=k,t=t,y=y_filt/np.linalg.norm(y_filt), model_name=model)

# get individual sinusoids 
single_sinusoids=single_sinusoid(theta=par_hat,m=k,t=t,y=y_filt/np.linalg.norm(y_filt), model_name=model)
A,Z=preds_split(theta=par_hat,m=k,t=t,y=y_filt/np.linalg.norm(y_filt), model_name=model)

# optional parameters amplitude and phase
phases=np.arctan2(np.imag(A),np.real(A)) #phase
amps=np.abs(A) # amplitudes

# view results in the time domain
plt.plot(t,y_filt,color="blue")
plt.plot(t,y_hat,color="black")
#plt.plot(t,y_filt-y_hat) # uncomment to view residuals

# define results in frequency domain
y_fft_hat=np.fft.fftshift(np.fft.fft(y_hat)) # fft of FID prediction
y_fft_cut=np.fft.fftshift(np.fft.fft(y_filt/np.linalg.norm(y_filt))) # fft of decimated FID 
y_fft_resi=y_fft_cut-y_fft_hat # residuals of the frequency domain 

# plot the results in hertz
for i in range(0,k):
     plt.plot(freq,(np.fft.fftshift(np.fft.fft(single_sinusoids[i]))),color="red")
plt.plot(freq,y_fft_cut,color="blue")
plt.plot(freq,(y_fft_hat),color="black")
#plt.plot(freq,(y_fft_resi),color="orange") # incude resuduals to the plot by uncommenting
plt.xlim(ppm2hz(high_ppm,SF,O1p), ppm2hz(low_ppm,SF,O1p))
plt.ylim(0,15)
plt.show()

# get results in ppm
omega=par_res['omega_est'] # extract frequency estimated in hz, it is also possible to find any other parameter this way

# plot results in ppm
ppm_val=ppm_axis1(time=t, O1=O1, fs=fs, fs_ppm=fs_ppm)
omega_ppm=hz2ppm(omega_hz=omega, SF=SF, O1p=O1p)

for i in range(0,k):
    plt.plot(ppm_val,np.fft.fftshift(np.fft.fft(single_sinusoids[i])),color="red")
plt.plot(ppm_val,(y_fft_cut),color="blue")
plt.plot(ppm_val,(y_fft_hat),color='black')
#plt.plot(ppm_val,(y_fft_resi),color="orange") # incude resuduals to the plot by uncommenting
plt.xlim(high_ppm,low_ppm)
plt.ylim(0,15)
plt.xlabel('ppm')  
plt.ylabel('Intensity')
plt.title("Model results( "+str(low_ppm)+"-"+str(high_ppm)+"ppm)", ) 
plt.show()

# %% [markdown]
# From here it is possible to save the results using the "result_csv_noboot" function. This save the estimated amplitudes (ratios and raw), frequencies (both in Hz and ppm) and a frequency distance matrix

# %%
omega=par_res['omega_est'] # frequency estimated in hz

j_mat=calc_couplings(omega=omega, k=k) # frequency distance matrix 

# use the result_csv to save results to a csv-file 
#result_csv(single_sinusoids,boot_samples,k,omega,SF,j_mat,O1,O1p) # uncomment if you want to save, (saved at current directory)

# %% [markdown]
# It is also possible to get error of the estimated parameters, this is done by estimating a confidence interval at a user defined level (set CI_level from 0 to 1) and a standard error for each parameter based on B number of bootstrap samples (set B from 1 to inf, recommend B=500+, if B>500 more accuracy, but longer computational time). This might take a while deepending on the size of the ROI, in the futre this will be done in parallel to speed up the process.

# %%
#%%capture 
# remove capture when trying out yourself! this is made here so the long computational printing does not take up too much space 

# get the bootstrap samples for each parameter
# note the parallel implementation does not work yet - set it to false and cores=1
boot_samples=onion_bootstrap_call(parallel=False,cores=1,B=500,par_hat=par_hat,low_ppm=low_ppm,high_ppm=high_ppm,model_name=model, CI_level=0.95,SF=SF,O1p=O1p,freq=freq,fs=fs, t=t, k=k, y=y_filt/np.linalg.norm(y_filt))
# Out:
# Epoch:01/epochs Loss: 4.29146e-01
# 0
# Epoch:01/epochs Loss: 3.14083e-01
# 1
# Epoch:01/epochs Loss: 2.06622e-01
# 2
# Epoch:01/epochs Loss: 1.65549e-01
# 3
# Epoch:01/epochs Loss: 5.00898e-02
# 4
# Epoch:01/epochs Loss: 8.22650e-02
# 5
# Epoch:01/epochs Loss: 2.18068e-02
# 6
# Epoch:01/epochs Loss: 1.11078e-01
# 7
# Epoch:01/epochs Loss: 6.39269e-02
# 8
# Epoch:01/epochs Loss: 6.18074e-02
# 9
# Epoch:01/epochs Loss: 1.60938e-01
# 10
# Epoch:01/epochs Loss: 2.11237e-01
# 11
# Epoch:01/epochs Loss: 2.84195e-01
# 12
# Epoch:01/epochs Loss: 1.33415e-01
# 13
# Epoch:01/epochs Loss: 1.90157e-01
# 14
# Epoch:01/epochs Loss: 5.85859e-01
# 15
# Epoch:01/epochs Loss: 6.26307e-02
# 16
# Epoch:01/epochs Loss: 6.83364e-02
# 17
# Epoch:01/epochs Loss: 1.89075e-01
# 18
# Epoch:01/epochs Loss: 3.83194e-01
# 19
# Epoch:01/epochs Loss: 2.61468e-01
# 20
# Epoch:01/epochs Loss: 2.35054e-01
# 21
# Epoch:01/epochs Loss: 9.86627e-02
# 22
# Epoch:01/epochs Loss: nan
# 23
# Epoch:01/epochs Loss: 4.13208e-01
# 24
# Epoch:01/epochs Loss: 5.04883e-01
# 25
# Epoch:01/epochs Loss: 9.81183e-02
# 26
# Epoch:01/epochs Loss: 9.71426e-02
# 27
# Epoch:01/epochs Loss: 1.00989e-01
# 28
# Epoch:01/epochs Loss: 8.55208e-02
# 29
# Epoch:01/epochs Loss: 2.09007e-01
# 30
# Epoch:01/epochs Loss: 2.36851e-01
# 31
# Epoch:01/epochs Loss: 6.49188e-02
# 32
# Epoch:01/epochs Loss: 4.73627e-01
# 33
# Epoch:01/epochs Loss: 4.66584e-01
# 34
# Epoch:01/epochs Loss: 4.17504e-02
# 35
# Epoch:01/epochs Loss: 6.52800e-02
# 36
# Epoch:01/epochs Loss: 2.04190e-01
# 37
# Epoch:01/epochs Loss: 2.33110e-01
# 38
# Epoch:01/epochs Loss: 5.87353e-02
# 39
# Epoch:01/epochs Loss: 1.74159e-02
# 40
# Epoch:01/epochs Loss: 8.90166e-02
# 41
# Epoch:01/epochs Loss: 6.55909e-02
# 42
# Epoch:01/epochs Loss: 1.25567e-01
# 43
# Epoch:01/epochs Loss: 1.13087e-01
# 44
# Epoch:01/epochs Loss: 1.01266e-01
# 45
# Epoch:01/epochs Loss: 2.82089e-01
# 46
# Epoch:01/epochs Loss: 2.61329e-01
# 47
# Epoch:01/epochs Loss: 1.58531e-01
# 48
# Epoch:01/epochs Loss: 2.99865e-01
# 49
# Epoch:01/epochs Loss: 1.80247e-01
# 50
# Epoch:01/epochs Loss: 2.29686e-01
# 51
# Epoch:01/epochs Loss: 5.97611e-02
# 52
# Epoch:01/epochs Loss: 5.85420e-02
# 53
# Epoch:01/epochs Loss: 5.88333e-02
# 54
# Epoch:01/epochs Loss: 2.10820e-02
# 55
# Epoch:01/epochs Loss: 2.40170e-01
# 56
# Epoch:01/epochs Loss: 6.60076e-02
# 57
# Epoch:01/epochs Loss: 5.98595e-02
# 58
# Epoch:01/epochs Loss: 1.55410e-01
# 59
# Epoch:01/epochs Loss: 4.13925e-02
# 60
# Epoch:01/epochs Loss: 2.04718e-01
# 61
# Epoch:01/epochs Loss: 3.45889e-01
# 62
# Epoch:01/epochs Loss: 2.25708e-01
# 63
# Epoch:01/epochs Loss: 9.54359e-01
# 64
# Epoch:01/epochs Loss: 1.51741e-01
# 65
# Epoch:01/epochs Loss: 6.22168e-02
# 66
# Epoch:01/epochs Loss: 1.34273e-01
# 67
# Epoch:01/epochs Loss: 6.67027e-02
# 68
# Epoch:01/epochs Loss: nan
# 69
# Epoch:01/epochs Loss: 6.31340e-02
# 70
# Epoch:01/epochs Loss: 1.66862e-01
# 71
# Epoch:01/epochs Loss: 4.08968e-02
# 72
# Epoch:01/epochs Loss: 7.42377e-01
# 73
# Epoch:01/epochs Loss: 5.72265e-03
# 74
# Epoch:01/epochs Loss: 3.25557e-01
# 75
# Epoch:01/epochs Loss: 4.41870e-02
# 76
# Epoch:01/epochs Loss: nan
# 77
# Epoch:01/epochs Loss: 1.98295e-01
# 78
# Epoch:01/epochs Loss: 6.55683e-02
# 79
# Epoch:01/epochs Loss: 5.88815e-02
# 80
# Epoch:01/epochs Loss: 1.38592e-01
# 81
# Epoch:01/epochs Loss: 1.34314e-01
# 82
# Epoch:01/epochs Loss: 2.62511e-01
# 83
# Epoch:01/epochs Loss: 9.92804e-06
# 84
# Epoch:01/epochs Loss: 3.47719e-01
# 85
# Epoch:01/epochs Loss: 6.44866e-02
# 86
# Epoch:01/epochs Loss: 3.50859e-01
# 87
# Epoch:01/epochs Loss: 2.65301e-01
# 88
# Epoch:01/epochs Loss: 2.26803e-01
# 89
# Epoch:01/epochs Loss: 1.25705e-01
# 90
# Epoch:01/epochs Loss: 3.92798e-01
# 91
# Epoch:01/epochs Loss: 1.33776e-01
# 92
# Epoch:01/epochs Loss: 1.35234e-01
# 93
# Epoch:01/epochs Loss: 2.68394e-01
# 94
# Epoch:01/epochs Loss: 6.66439e-02
# 95
# Epoch:01/epochs Loss: 1.84993e-01
# 96
# Epoch:01/epochs Loss: 1.43142e-01
# 97
# Epoch:01/epochs Loss: 5.53061e-02
# 98
# Epoch:01/epochs Loss: 4.98980e-01
# 99
# Epoch:01/epochs Loss: 2.33945e-01
# 100
# Epoch:01/epochs Loss: 6.46192e-02
# 101
# Epoch:01/epochs Loss: 6.18019e-02
# 102
# Epoch:01/epochs Loss: 6.88613e-01
# 103
# Epoch:01/epochs Loss: 3.01761e-01
# 104
# Epoch:01/epochs Loss: 7.28083e-02
# 105
# Epoch:01/epochs Loss: 1.72917e-01
# 106
# Epoch:01/epochs Loss: 6.44929e-02
# 107
# Epoch:01/epochs Loss: 1.55573e-01
# 108
# Epoch:01/epochs Loss: 1.59716e-01
# 109
# Epoch:01/epochs Loss: 1.22459e-01
# 110
# Epoch:01/epochs Loss: 6.09453e-02
# 111
# Epoch:01/epochs Loss: nan
# 112
# Epoch:01/epochs Loss: 1.35235e-01
# 113
# Epoch:01/epochs Loss: 1.94946e-01
# 114
# Epoch:01/epochs Loss: 2.29163e-01
# 115
# Epoch:01/epochs Loss: 9.95795e-02
# 116
# Epoch:01/epochs Loss: 9.48018e-02
# 117
# Epoch:01/epochs Loss: 7.77720e-02
# 118
# Epoch:01/epochs Loss: 4.16967e-02
# 119
# Epoch:01/epochs Loss: 1.47133e-01
# 120
# Epoch:01/epochs Loss: nan
# 121
# Epoch:01/epochs Loss: 1.19501e-01
# 122
# Epoch:01/epochs Loss: 6.53885e-01
# 123
# Epoch:01/epochs Loss: 3.49654e-01
# 124
# Epoch:01/epochs Loss: 1.83088e-01
# 125
# Epoch:01/epochs Loss: 2.66021e-01
# 126
# Epoch:01/epochs Loss: 1.30726e-01
# 127
# Epoch:01/epochs Loss: 2.13175e-01
# 128
# Epoch:01/epochs Loss: 1.07205e-01
# 129
# Epoch:01/epochs Loss: 7.57664e-02
# 130
# Epoch:01/epochs Loss: 5.83943e-02
# 131
# Epoch:01/epochs Loss: 7.57576e-01
# 132
# Epoch:01/epochs Loss: 8.07830e-01
# 133
# Epoch:01/epochs Loss: 7.26357e-01
# 134
# Epoch:01/epochs Loss: 1.80768e-01
# 135
# Epoch:01/epochs Loss: 1.40530e-01
# 136
# Epoch:01/epochs Loss: 1.17628e-01
# 137
# Epoch:01/epochs Loss: 2.00447e-01
# 138
# Epoch:01/epochs Loss: 8.28737e-02
# 139
# Epoch:01/epochs Loss: 1.64562e-01
# 140
# Epoch:01/epochs Loss: 1.55533e-01
# 141
# Epoch:01/epochs Loss: 3.87419e-01
# 142
# Epoch:01/epochs Loss: nan
# 143
# Epoch:01/epochs Loss: 1.34902e-01
# 144
# Epoch:01/epochs Loss: 9.23038e-02
# 145
# Epoch:01/epochs Loss: 3.19824e-01
# 146
# Epoch:01/epochs Loss: 2.06236e-01
# 147
# Epoch:01/epochs Loss: 1.51799e-01
# 148
# Epoch:01/epochs Loss: 2.23809e-02
# 149
# Epoch:01/epochs Loss: 1.15686e-01
# 150
# Epoch:01/epochs Loss: 1.01891e-02
# 151
# Epoch:01/epochs Loss: 1.40438e-01
# 152
# Epoch:01/epochs Loss: 8.61384e-02
# 153
# Epoch:01/epochs Loss: 5.49498e-01
# 154
# Epoch:01/epochs Loss: 5.73764e-02
# 155
# Epoch:01/epochs Loss: 1.05236e-01
# 156
# Epoch:01/epochs Loss: 3.63139e-01
# 157
# Epoch:01/epochs Loss: 3.87937e-01
# 158
# Epoch:01/epochs Loss: 3.09035e-01
# 159
# Epoch:01/epochs Loss: 2.27772e-01
# 160
# Epoch:01/epochs Loss: 1.01968e-01
# 161
# Epoch:01/epochs Loss: 1.56826e-01
# 162
# Epoch:01/epochs Loss: 9.34116e-01
# 163
# Epoch:01/epochs Loss: nan
# 164
# Epoch:01/epochs Loss: 2.33379e-01
# 165
# Epoch:01/epochs Loss: 1.21923e-01
# 166
# Epoch:01/epochs Loss: 1.36360e-01
# 167
# Epoch:01/epochs Loss: 2.20303e-01
# 168
# Epoch:01/epochs Loss: 6.51787e-02
# 169
# Epoch:01/epochs Loss: 4.77917e-02
# 170
# Epoch:01/epochs Loss: 5.87549e-02
# 171
# Epoch:01/epochs Loss: 3.06034e-01
# 172
# Epoch:01/epochs Loss: 3.49933e-02
# 173
# Epoch:01/epochs Loss: 5.84977e-02
# 174
# Epoch:01/epochs Loss: 1.80530e-01
# 175
# Epoch:01/epochs Loss: 3.32503e-01
# 176
# Epoch:01/epochs Loss: 4.60212e-01
# 177
# Epoch:01/epochs Loss: 2.91360e-01
# 178
# Epoch:01/epochs Loss: 2.01815e-01
# 179
# Epoch:01/epochs Loss: 1.11593e-01
# 180
# Epoch:01/epochs Loss: 1.65364e-01
# 181
# Epoch:01/epochs Loss: 2.93712e-01
# 182
# Epoch:01/epochs Loss: 9.20744e-03
# 183
# Epoch:01/epochs Loss: 1.79906e-01
# 184
# Epoch:01/epochs Loss: nan
# 185
# Epoch:01/epochs Loss: 1.51857e-02
# 186
# Epoch:01/epochs Loss: 5.87030e-02
# 187
# Epoch:01/epochs Loss: 8.27753e-02
# 188
# Epoch:01/epochs Loss: 3.29258e-01
# 189
# Epoch:01/epochs Loss: 4.30049e-01
# 190
# Epoch:01/epochs Loss: nan
# 191
# Epoch:01/epochs Loss: 1.54011e-01
# 192
# Epoch:01/epochs Loss: 6.29590e-02
# 193
# Epoch:01/epochs Loss: 5.89711e-02
# 194
# Epoch:01/epochs Loss: 1.93673e-01
# 195
# Epoch:01/epochs Loss: 1.41350e-01
# 196
# Epoch:01/epochs Loss: 1.68092e-01
# 197
# Epoch:01/epochs Loss: 3.89835e-01
# 198
# Epoch:01/epochs Loss: 1.42936e-01
# 199
# Epoch:01/epochs Loss: 1.68937e-01
# 200
# Epoch:01/epochs Loss: 2.99054e-01
# 201
# Epoch:01/epochs Loss: 2.83903e-01
# 202
# Epoch:01/epochs Loss: 9.99474e-03
# 203
# Epoch:01/epochs Loss: 9.14411e-02
# 204
# Epoch:01/epochs Loss: 6.86221e-02
# 205
# Epoch:01/epochs Loss: 4.32431e-01
# 206
# Epoch:01/epochs Loss: 1.73511e-01
# 207
# Epoch:01/epochs Loss: nan
# 208
# Epoch:01/epochs Loss: 6.26378e-02
# 209
# Epoch:01/epochs Loss: 1.08946e-01
# 210
# Epoch:01/epochs Loss: 3.21343e-02
# 211
# Epoch:01/epochs Loss: 7.31679e-02
# 212
# Epoch:01/epochs Loss: 7.16584e-01
# 213
# Epoch:01/epochs Loss: 7.10068e-02
# 214
# Epoch:01/epochs Loss: 6.83091e-02
# 215
# Epoch:01/epochs Loss: 2.40909e-01
# 216
# Epoch:01/epochs Loss: 2.09320e-01
# 217
# Epoch:01/epochs Loss: 6.02869e-02
# 218
# Epoch:01/epochs Loss: 1.14328e-01
# 219
# Epoch:01/epochs Loss: 6.88784e-02
# 220
# Epoch:01/epochs Loss: 1.17821e-02
# 221
# Epoch:01/epochs Loss: 6.19398e-02
# 222
# Epoch:01/epochs Loss: 5.92214e-02
# 223
# Epoch:01/epochs Loss: 1.85243e-01
# 224
# Epoch:01/epochs Loss: 1.62204e-01
# 225
# Epoch:01/epochs Loss: 2.16863e-01
# 226
# Epoch:01/epochs Loss: 5.90525e-02
# 227
# Epoch:01/epochs Loss: 8.54580e-02
# 228
# Epoch:01/epochs Loss: 1.20906e-01
# 229
# Epoch:01/epochs Loss: 8.05974e-01
# 230
# Epoch:01/epochs Loss: 4.08167e-01
# 231
# Epoch:01/epochs Loss: 2.06833e-02
# 232
# Epoch:01/epochs Loss: 9.54553e-02
# 233
# Epoch:01/epochs Loss: 1.63882e-01
# 234
# Epoch:01/epochs Loss: 5.96122e-02
# 235
# Epoch:01/epochs Loss: 9.92347e-02
# 236
# Epoch:01/epochs Loss: 8.16070e-02
# 237
# Epoch:01/epochs Loss: 1.28962e-01
# 238
# Epoch:01/epochs Loss: 1.09243e-01
# 239
# Epoch:01/epochs Loss: 9.04298e-02
# 240
# Epoch:01/epochs Loss: 1.45549e-02
# 241
# Epoch:01/epochs Loss: 1.08640e-01
# 242
# Epoch:01/epochs Loss: 1.80874e-01
# 243
# Epoch:01/epochs Loss: 4.44942e-01
# 244
# Epoch:01/epochs Loss: 5.99906e-02
# 245
# Epoch:01/epochs Loss: 7.00536e-02
# 246
# Epoch:01/epochs Loss: 1.50300e-01
# 247
# Epoch:01/epochs Loss: 2.98407e-01
# 248
# Epoch:01/epochs Loss: 1.80354e-01
# 249
# Epoch:01/epochs Loss: 1.03014e-01
# 250
# Epoch:01/epochs Loss: 2.48960e-01
# 251
# Epoch:01/epochs Loss: 1.43469e-01
# 252
# Epoch:01/epochs Loss: 6.28416e-02
# 253
# Epoch:01/epochs Loss: 3.13740e-01
# 254
# Epoch:01/epochs Loss: 1.07706e+00
# 255
# Epoch:01/epochs Loss: 7.74339e-02
# 256
# Epoch:01/epochs Loss: 6.88708e-02
# 257
# Epoch:01/epochs Loss: nan
# 258
# Epoch:01/epochs Loss: 1.25480e-01
# 259
# Epoch:01/epochs Loss: 1.88177e-02
# 260
# Epoch:01/epochs Loss: 4.11696e-02
# 261
# Epoch:01/epochs Loss: 1.04363e-01
# 262
# Epoch:01/epochs Loss: 2.55033e-01
# 263
# Epoch:01/epochs Loss: 9.10249e-02
# 264
# Epoch:01/epochs Loss: 5.80765e-02
# 265
# Epoch:01/epochs Loss: 1.08892e-01
# 266
# Epoch:01/epochs Loss: 1.36280e-01
# 267
# Epoch:01/epochs Loss: 3.40338e-06
# 268
# Epoch:01/epochs Loss: 5.86925e-02
# 269
# Epoch:01/epochs Loss: 1.39239e-01
# 270
# Epoch:01/epochs Loss: 1.03680e+00
# 271
# Epoch:01/epochs Loss: 9.75385e-02
# 272
# Epoch:01/epochs Loss: 2.67906e-01
# 273
# Epoch:01/epochs Loss: 1.38875e-01
# 274
# Epoch:01/epochs Loss: 1.26664e-01
# 275
# Epoch:01/epochs Loss: 9.22994e-01
# 276
# Epoch:01/epochs Loss: 4.51348e-02
# 277
# Epoch:01/epochs Loss: 2.13707e-01
# 278
# Epoch:01/epochs Loss: 2.77332e-01
# 279
# Epoch:01/epochs Loss: 6.08427e-02
# 280
# Epoch:01/epochs Loss: 2.19933e-01
# 281
# Epoch:01/epochs Loss: 1.87316e-01
# 282
# Epoch:01/epochs Loss: 2.05327e-01
# 283
# Epoch:01/epochs Loss: 7.10281e-02
# 284
# Epoch:01/epochs Loss: 9.65309e-02
# 285
# Epoch:01/epochs Loss: 1.80603e-01
# 286
# Epoch:01/epochs Loss: 4.83049e-01
# 287
# Epoch:01/epochs Loss: 5.83020e-02
# 288
# Epoch:01/epochs Loss: 3.55118e-01
# 289
# Epoch:01/epochs Loss: 3.89818e-02
# 290
# Epoch:01/epochs Loss: 1.43382e-01
# 291
# Epoch:01/epochs Loss: 1.27849e-02
# 292
# Epoch:01/epochs Loss: 1.28310e-01
# 293
# Epoch:01/epochs Loss: 1.44756e-01
# 294
# Epoch:01/epochs Loss: 1.58841e-01
# 295
# Epoch:01/epochs Loss: 1.90233e-01
# 296
# Epoch:01/epochs Loss: 2.51416e-01
# 297
# Epoch:01/epochs Loss: 5.44328e-02
# 298
# Epoch:01/epochs Loss: 2.21529e-01
# 299
# Epoch:01/epochs Loss: 3.66562e-06
# 300
# Epoch:01/epochs Loss: 6.80200e-01
# 301
# Epoch:01/epochs Loss: 4.04164e-01
# 302
# Epoch:01/epochs Loss: 7.39941e-03
# 303
# Epoch:01/epochs Loss: 1.20808e-01
# 304
# Epoch:01/epochs Loss: 1.46335e-01
# 305
# Epoch:01/epochs Loss: 8.98765e-02
# 306
# Epoch:01/epochs Loss: 5.77594e-01
# 307
# Epoch:01/epochs Loss: 4.06718e-01
# 308
# Epoch:01/epochs Loss: 3.64056e-01
# 309
# Epoch:01/epochs Loss: 6.78520e-02
# 310
# Epoch:01/epochs Loss: 7.97954e-02
# 311
# Epoch:01/epochs Loss: 3.26308e-01
# 312
# Epoch:01/epochs Loss: 1.15634e-02
# 313
# Epoch:01/epochs Loss: 7.83098e-02
# 314
# Epoch:01/epochs Loss: 1.47754e-01
# 315
# Epoch:01/epochs Loss: 2.66740e-02
# 316
# Epoch:01/epochs Loss: 2.47026e-02
# 317
# Epoch:01/epochs Loss: 1.84406e-01
# 318
# Epoch:01/epochs Loss: nan
# 319
# Epoch:01/epochs Loss: 5.81720e-02
# 320
# Epoch:01/epochs Loss: 6.44159e-02
# 321
# Epoch:01/epochs Loss: 1.55188e-01
# 322
# Epoch:01/epochs Loss: 3.61576e-02
# 323
# Epoch:01/epochs Loss: 8.41305e-02
# 324
# Epoch:01/epochs Loss: 9.13253e-02
# 325
# Epoch:01/epochs Loss: 9.75956e-02
# 326
# Epoch:01/epochs Loss: 8.51311e-02
# 327
# Epoch:01/epochs Loss: 5.89038e-02
# 328
# Epoch:01/epochs Loss: 2.15081e-01
# 329
# Epoch:01/epochs Loss: 2.25671e-01
# 330
# Epoch:01/epochs Loss: 1.30930e-01
# 331
# Epoch:01/epochs Loss: 2.66740e-01
# 332
# Epoch:01/epochs Loss: 1.01483e-01
# 333
# Epoch:01/epochs Loss: 8.37226e-02
# 334
# Epoch:01/epochs Loss: 1.24178e-01
# 335
# Epoch:01/epochs Loss: nan
# 336
# Epoch:01/epochs Loss: 4.05857e-02
# 337
# Epoch:01/epochs Loss: 1.96329e-01
# 338
# Epoch:01/epochs Loss: 6.98175e-01
# 339
# Epoch:01/epochs Loss: 5.35025e-03
# 340
# Epoch:01/epochs Loss: 1.70354e-01
# 341
# Epoch:01/epochs Loss: 6.93356e-03
# 342
# Epoch:01/epochs Loss: 1.37656e-01
# 343
# Epoch:01/epochs Loss: 2.29385e-03
# 344
# Epoch:01/epochs Loss: 1.51315e-01
# 345
# Epoch:01/epochs Loss: 1.28974e-01
# 346
# Epoch:01/epochs Loss: 2.58182e-01
# 347
# Epoch:01/epochs Loss: 7.70034e-02
# 348
# Epoch:01/epochs Loss: 4.99699e-01
# 349
# Epoch:01/epochs Loss: 2.76309e-01
# 350
# Epoch:01/epochs Loss: 3.54293e-01
# 351
# Epoch:01/epochs Loss: nan
# 352
# Epoch:01/epochs Loss: 5.48710e-03
# 353
# Epoch:01/epochs Loss: 2.36390e-01
# 354
# Epoch:01/epochs Loss: 3.03594e-02
# 355
# Epoch:01/epochs Loss: 1.03717e-01
# 356
# Epoch:01/epochs Loss: 1.10589e-01
# 357
# Epoch:01/epochs Loss: 2.20175e-01
# 358
# Epoch:01/epochs Loss: 1.20291e-01
# 359
# Epoch:01/epochs Loss: 1.65593e-02
# 360
# Epoch:01/epochs Loss: 1.87896e-01
# 361
# Epoch:01/epochs Loss: 6.05479e-02
# 362
# Epoch:01/epochs Loss: 3.38524e-01
# 363
# Epoch:01/epochs Loss: 6.99491e-02
# 364
# Epoch:01/epochs Loss: 2.29503e-03
# 365
# Epoch:01/epochs Loss: 2.87862e-01
# 366
# Epoch:01/epochs Loss: 8.26374e-02
# 367
# Epoch:01/epochs Loss: 1.10547e-01
# 368
# Epoch:01/epochs Loss: 1.06432e-01
# 369
# Epoch:01/epochs Loss: 1.51830e-01
# 370
# Epoch:01/epochs Loss: 3.30340e-01
# 371
# Epoch:01/epochs Loss: 1.24298e-01
# 372
# Epoch:01/epochs Loss: 1.19383e-01
# 373
# Epoch:01/epochs Loss: 1.09287e-01
# 374
# Epoch:01/epochs Loss: 9.67431e-02
# 375
# Epoch:01/epochs Loss: 4.29647e-01
# 376
# Epoch:01/epochs Loss: 1.58422e-01
# 377
# Epoch:01/epochs Loss: 1.75252e-01
# 378
# Epoch:01/epochs Loss: 2.40927e-02
# 379
# Epoch:01/epochs Loss: 5.50714e-01
# 380
# Epoch:01/epochs Loss: 1.20263e-01
# 381
# Epoch:01/epochs Loss: 3.30728e-02
# 382
# Epoch:01/epochs Loss: 5.26044e-01
# 383
# Epoch:01/epochs Loss: 1.33789e-01
# 384
# Epoch:01/epochs Loss: 4.25241e-01
# 385
# Epoch:01/epochs Loss: 1.20365e-01
# 386
# Epoch:01/epochs Loss: 2.80547e-01
# 387
# Epoch:01/epochs Loss: 1.02055e-01
# 388
# Epoch:01/epochs Loss: 6.58846e-03
# 389
# Epoch:01/epochs Loss: 3.19604e-01
# 390
# Epoch:01/epochs Loss: 5.84525e-02
# 391
# Epoch:01/epochs Loss: 8.95953e-02
# 392
# Epoch:01/epochs Loss: 1.36180e-01
# 393
# Epoch:01/epochs Loss: 1.45367e-01
# 394
# Epoch:01/epochs Loss: 1.81555e-01
# 395
# Epoch:01/epochs Loss: 1.70276e-01
# 396
# Epoch:01/epochs Loss: 1.58554e-01
# 397
# Epoch:01/epochs Loss: nan
# 398
# Epoch:01/epochs Loss: 7.14288e-02
# 399
# Epoch:01/epochs Loss: 2.48276e-01
# 400
# Epoch:01/epochs Loss: 1.97016e-01
# 401
# Epoch:01/epochs Loss: 2.93161e-02
# 402
# Epoch:01/epochs Loss: 2.63333e-01
# 403
# Epoch:01/epochs Loss: 1.63598e-01
# 404
# Epoch:01/epochs Loss: 2.18776e-01
# 405
# Epoch:01/epochs Loss: 6.69718e-02
# 406
# Epoch:01/epochs Loss: 9.95498e-02
# 407
# Epoch:01/epochs Loss: 4.98712e-01
# 408
# Epoch:01/epochs Loss: 3.96676e-01
# 409
# Epoch:01/epochs Loss: 1.27073e-01
# 410
# Epoch:01/epochs Loss: 4.84678e-03
# 411
# Epoch:01/epochs Loss: 9.25326e-01
# 412
# Epoch:01/epochs Loss: nan
# 413
# Epoch:01/epochs Loss: 1.51966e-01
# 414
# Epoch:01/epochs Loss: 7.78043e-02
# 415
# Epoch:01/epochs Loss: 2.21786e-01
# 416
# Epoch:01/epochs Loss: 8.51836e-02
# 417
# Epoch:01/epochs Loss: 5.87777e-02
# 418
# Epoch:01/epochs Loss: 2.06740e-01
# 419
# Epoch:01/epochs Loss: 4.09620e-01
# 420
# Epoch:01/epochs Loss: 1.74241e-02
# 421
# Epoch:01/epochs Loss: 1.17281e-01
# 422
# Epoch:01/epochs Loss: 1.74918e-02
# 423
# Epoch:01/epochs Loss: 6.62146e-02
# 424
# Epoch:01/epochs Loss: nan
# 425
# Epoch:01/epochs Loss: 1.88320e-02
# 426
# Epoch:01/epochs Loss: 1.26271e-02
# 427
# Epoch:01/epochs Loss: 8.41695e-02
# 428
# Epoch:01/epochs Loss: nan
# 429
# Epoch:01/epochs Loss: 2.17985e-01
# 430
# Epoch:01/epochs Loss: 4.39490e-01
# 431
# Epoch:01/epochs Loss: 1.01737e-02
# 432
# Epoch:01/epochs Loss: 6.77864e-02
# 433
# Epoch:01/epochs Loss: 2.59134e-02
# 434
# Epoch:01/epochs Loss: 2.84472e-01
# 435
# Epoch:01/epochs Loss: 1.18896e-01
# 436
# Epoch:01/epochs Loss: 1.68407e-01
# 437
# Epoch:01/epochs Loss: 3.03268e-01
# 438
# Epoch:01/epochs Loss: 3.06439e-01
# 439
# Epoch:01/epochs Loss: 5.91304e-02
# 440
# Epoch:01/epochs Loss: 1.10637e-02
# 441
# Epoch:01/epochs Loss: 5.70282e-01
# 442
# Epoch:01/epochs Loss: 1.24172e-01
# 443
# Epoch:01/epochs Loss: 5.90224e-02
# 444
# Epoch:01/epochs Loss: 6.33067e-02
# 445
# Epoch:01/epochs Loss: 1.42773e-01
# 446
# Epoch:01/epochs Loss: 8.98703e-02
# 447
# Epoch:01/epochs Loss: 6.96069e-01
# 448
# Epoch:01/epochs Loss: 2.20603e-01
# 449
# Epoch:01/epochs Loss: 5.90057e-02
# 450
# Epoch:01/epochs Loss: 2.71484e-01
# 451
# Epoch:01/epochs Loss: 2.60514e-02
# 452
# Epoch:01/epochs Loss: 2.24239e-03
# 453
# Epoch:01/epochs Loss: 1.10548e-01
# 454
# Epoch:01/epochs Loss: 8.87798e-02
# 455
# Epoch:01/epochs Loss: 1.30661e-01
# 456
# Epoch:01/epochs Loss: 1.89137e-01
# 457
# Epoch:01/epochs Loss: 9.70383e-02
# 458
# Epoch:01/epochs Loss: 6.70375e-01
# 459
# Epoch:01/epochs Loss: 8.09170e-02
# 460
# Epoch:01/epochs Loss: 1.36575e-01
# 461
# Epoch:01/epochs Loss: 2.79291e-01
# 462
# Epoch:01/epochs Loss: 2.51531e-02
# 463
# Epoch:01/epochs Loss: nan
# 464
# Epoch:01/epochs Loss: 2.53833e-01
# 465
# Epoch:01/epochs Loss: 2.52314e-02
# 466
# Epoch:01/epochs Loss: 5.93799e-02
# 467
# Epoch:01/epochs Loss: 1.47268e-01
# 468
# Epoch:01/epochs Loss: 1.22709e-01
# 469
# Epoch:01/epochs Loss: 2.14338e-01
# 470
# Epoch:01/epochs Loss: 1.18558e-01
# 471
# Epoch:01/epochs Loss: 1.27189e-01
# 472
# Epoch:01/epochs Loss: 2.29939e-05
# 473
# Epoch:01/epochs Loss: nan
# 474
# Epoch:01/epochs Loss: 5.13659e-02
# 475
# Epoch:01/epochs Loss: 1.08613e-01
# 476
# Epoch:01/epochs Loss: 1.40972e-01
# 477
# Epoch:01/epochs Loss: 5.07742e-01
# 478
# Epoch:01/epochs Loss: 2.57140e-01
# 479
# Epoch:01/epochs Loss: 2.41690e-01
# 480
# Epoch:01/epochs Loss: 2.61337e-01
# 481
# Epoch:01/epochs Loss: 6.86732e-02
# 482
# Epoch:01/epochs Loss: 5.33255e-01
# 483
# Epoch:01/epochs Loss: 6.97038e-02
# 484
# Epoch:01/epochs Loss: 3.17754e-02
# 485
# Epoch:01/epochs Loss: 1.01325e-01
# 486
# Epoch:01/epochs Loss: 2.43168e-01
# 487
# Epoch:01/epochs Loss: 1.19738e-01
# 488
# Epoch:01/epochs Loss: 7.89326e-02
# 489
# Epoch:01/epochs Loss: 2.26441e-01
# 490
# Epoch:01/epochs Loss: 5.84048e-02
# 491
# Epoch:01/epochs Loss: 1.06917e-01
# 492
# Epoch:01/epochs Loss: 5.13620e-01
# 493
# Epoch:01/epochs Loss: 5.10599e-02
# 494
# Epoch:01/epochs Loss: 1.99266e-01
# 495
# Epoch:01/epochs Loss: 1.94910e-01
# 496
# Epoch:01/epochs Loss: 1.99828e-04
# 497
# Epoch:01/epochs Loss: 3.01900e-01
# 498
# Epoch:01/epochs Loss: 4.14651e-02
# 499
# 704.4623582363129

# %% [markdown]
# Finally one may collect all key results and import these in a seperate folder generating one CSV per ROI. the CSV contains a coupling matrix, parameter estimates, that is frequency (hz and ppm), amplitude ratios, uncertainties of the frequencies.
#
# One can do some slight altering to get all the model paramters in the CSV, but per default we keep these out as they are not very meaningfull when interperting data as they contribute mainly to the amplitude ratio estimations.
#
# The content of a ROI is shown below to increase understanding. To extract the results from python, the function of result_csv is called to get a CSV of the wanted ROI containing the output of the above dataframes.

# %%
# the content of the CSV showcased

# frequency distance matrix 
j_mat=calc_couplings(omega=omega, k=k)

# get idx of overlaps
idx_list=getoverlaps(boot_samples,omega_ppm, k)

# count the overlaps
overlaps=count_overlaps(idx_list, k) 

# amplitudes ratio
amp_ratios=amp_ratio(peaks=single_sinusoids, k=k)

# raw amplitude height (newly updated)
raw_amps=get_amps(peaks=single_sinusoids, k=k)

boot_samples['omega_std'].index=range(k)

#table of uncertainties
res_uncertantinty=pd.DataFrame(({'omega_hz_error':boot_samples['omega_std'],
                                'omega_hz_CI_lower':boot_samples['omega_CI_lower']+O1,
                                'omega_hz_CI_upper':boot_samples['omega_CI_upper']+O1,
                                'omega_ppm_error':hz2ppm(omega_hz=boot_samples['omega_boot'], SF=SF, O1p=O1p).T.std(),
                                'omega_ppm_CI_lower':hz2ppm(omega_hz=boot_samples['omega_CI_lower'], SF=SF, O1p=O1p),
                                'omega_ppm_CI_upper':hz2ppm(omega_hz=boot_samples['omega_CI_upper'], SF=SF, O1p=O1p)
    }))
res_uncertantinty.index = range(k)


# table of regional results
res_region=pd.DataFrame(({'amp_ratio':amp_ratios,
                         'omega_hz':omega+O1,
                         'omega_ppm':omega_ppm,
                         'overlaps': overlaps,
                          'raw_amps':raw_amps
                         }))

res_combo=pd.concat([res_region,res_uncertantinty,j_mat],axis=1)


# use the result_csv to save results to a csv-file - uncomment if you want to save 
#result_csv(single_sinusoids,boot_samples,k,omega,SF,j_mat,O1,O1p)

# %% [markdown]
# Note to interpret the frequency distance matrix, the diagnoal elements represents the current peak marked with a 0 and the off diagnoals are the distances bewteen the current peak and the peaks sourounding it.

# %%
# plot results in ppm
omega=par_res['omega_est'] # frequency estimated in hz

j_mat=calc_couplings(omega=omega, k=k) # frequecny distance matrix 

# get residuals 
y_fft_resi=y_fft_cut-y_fft_hat # residuals of the frequency domain 

# plot results in ppm
ppm_val=ppm_axis1(time=t, O1=O1, fs=fs, fs_ppm=fs_ppm)
omega_ppm=hz2ppm(omega_hz=omega, SF=SF, O1p=O1p)
idx_list=getoverlaps(boot_samples,omega_ppm, k) # comment out if no boostrap samples have been genreated

for i in range(0,k):
    plt.plot(ppm_val,np.fft.fftshift(np.fft.fft(single_sinusoids[i])),color="red")
for i in range(0,len(idx_list)): # comment out this loop if no bootstrap samples has been made
    ppm_cord_idx=np.argmax(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]])))
    plt.scatter(ppm_val[ppm_cord_idx],max(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]]))),color="green")   
plt.plot(ppm_val,(y_fft_cut),color="blue",label="Raw data")
plt.plot(ppm_val,(y_fft_hat),color='green',label="Fitted model")
plt.plot(ppm_val,(y_fft_resi),color="black",label="Residuals")

plt.xlim(high_ppm,low_ppm)
plt.xlim(3.43,3.36)
#plt.ylim(0,60)
plt.xlabel('ppm')  
plt.ylabel('Intensity')
#
plt.title("Model results( "+str(low_ppm)+"-"+str(high_ppm)+"ppm)", ) 
plt.show()

# save the plot to current directory 
#plt.savefig('NMR_onion_demo.pdf')  


for i in range(0,k):
    plt.plot(ppm_val,np.fft.fftshift(np.fft.fft(single_sinusoids[i])),color="red")
for i in range(0,len(idx_list)): # comment out this loop if no bootstrap samples has been made
    ppm_cord_idx=np.argmax(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]])))
    plt.scatter(ppm_val[ppm_cord_idx],max(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]]))),color="green")   
plt.plot(ppm_val,(y_fft_cut),color="blue",label="Raw data")
plt.plot(ppm_val,(y_fft_hat),color='green',label="Fitted model")
plt.plot(ppm_val,(y_fft_resi),color="black",label="Residuals")

plt.xlim(high_ppm,low_ppm)
plt.xlim(3.515,3.47)
#plt.ylim(0,60)
plt.xlabel('ppm')  
plt.ylabel('Intensity')
#
plt.title("Model results( "+str(low_ppm)+"-"+str(high_ppm)+"ppm)", ) 
plt.show()

# save the plot to current directory 
#plt.savefig('NMR_onion_demo.pdf')  


for i in range(0,k):
    plt.plot(ppm_val,np.fft.fftshift(np.fft.fft(single_sinusoids[i])),color="red")
for i in range(0,len(idx_list)): # comment out this loop if no bootstrap samples has been made
    ppm_cord_idx=np.argmax(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]])))
    plt.scatter(ppm_val[ppm_cord_idx],max(np.fft.fftshift(np.fft.fft(single_sinusoids[idx_list[i]]))),color="green")   
plt.plot(ppm_val,(y_fft_cut),color="blue",label="Raw data")
plt.plot(ppm_val,(y_fft_hat),color='green',label="Fitted model")
plt.plot(ppm_val,(y_fft_resi),color="black",label="Residuals")

plt.xlim(high_ppm,low_ppm)
plt.xlim(3.58,3.51)
#plt.ylim(0,60)
plt.xlabel('ppm')  
plt.ylabel('Intensity')
#
plt.title("Model results( "+str(low_ppm)+"-"+str(high_ppm)+"ppm)", ) 
plt.show()

# %% [markdown]
# The results can also be obtained and plotted in the time domain if desired, by using the code below

# %%
plt.plot(y_filt/np.linalg.norm(y_filt),color="blue") # normalized filtered data 
plt.plot(y_hat,color="green") # estimated model
plt.show()

plt.plot(y_hat-y_filt/np.linalg.norm(y_filt)) # resiudals

# %% [markdown]
# A last fearure one can get after extacting the results are the plotting of parameter uncertainties. It is possible to plot view where potential false peaks are located in in a given ROI. These are marked by a green dot. one can also plot the boostrap samples of a particular peak if needed to view potenital overlaps, here we are showing the peak at peaks around 2.405 ppm. At the moment this is done manually, but in the future an automation will be made.

# %%
# plot the CI of a desired peak
omega_samples=boot_samples['omega_boot']
omega_samples.index = range(k)

df_max=omega_samples.T.max(axis=1).max()+O1
df_min=omega_samples.T.min(axis=1).min()+O1

sub_roi_CIl=res_combo['omega_hz_CI_lower']
sub_roi_CIu=res_combo['omega_hz_CI_upper']

sub_roi_CIl.index = range(k)
sub_roi_CIu.index = range(k)



_, bins, _ = plt.hist(omega_samples.T[idx_list[0]], bins=500,range=(df_min,df_max))
plt.title("boostrap samples of two peaks")
plt.xlabel("Hz")
plt.ylabel("Emperical density")
plt.xlim(2720,2726) # set the plot limits in Hz 
_= plt.hist(omega_samples.T[idx_list[0]]+O1,color="r", bins=bins,density=True)  # you have to know the number of the peak you are looking for
_= plt.hist(omega_samples.T[idx_list[1]]+O1,ec="b",fc="none", bins=bins,density=True)    
plt.axvline(sub_roi_CIl[idx_list[0]],color="green")
plt.axvline(sub_roi_CIu[idx_list[1]],color="green")
plt.axvline(sub_roi_CIl[idx_list[0]],color="black")
plt.axvline(sub_roi_CIu[idx_list[1]],color="black")
plt.show()
